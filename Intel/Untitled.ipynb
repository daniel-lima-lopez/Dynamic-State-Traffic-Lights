# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set_context("poster")

# %%
df=pd.read_csv('wait.csv')

# %%
plt.figure(figsize=(18, 8))  # Adjust the figure size as needed
plt.plot(df)
plt.title('Car wait at a street')
# plt.savefig(folder+'loss_disc_'+test_name+'.png')
# Out:
# Text(0.5, 1.0, 'Car wait at a street')

# %%
df2=pd.read_csv('numcar.csv')

# %%
plt.figure(figsize=(18, 8))  # Adjust the figure size as needed
plt.plot(df2)
plt.title('Number of cars')
# plt.savefig(folder+'loss_disc_'+test_name+'.png')
# Out:
# Text(0.5, 1.0, 'Number of cars')
